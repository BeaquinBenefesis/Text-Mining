# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.ontology.synonym_tools import compare_synfiles

# %%
pw = '/mnt/raidbio2/extproj/projekte/textmining/mirnaTextmining/mirClassification/data/synonyms/final/pw'
#upa = '/mnt/raidbio2/extproj/projekte/textmining/mirnaTextmining/mirClassification/data/synonyms/final/upa'
go = '/mnt/raidbio2/extproj/projekte/textmining/mirnaTextmining/mirClassification/data/synonyms/final/go.syn'

# %%
print(compare_synfiles(pw, go, print_overlapping=True))
# Out:
# pw: Read 2704 lines with 3225 terms.
#
# Terms appearing more than once:
#   'dermatological drug pathway': 2 times
#   'congenital adrenal hyperplasia pathway': 2 times
#   'hypermethioninemia pathway': 2 times
#   'indometacin drug pathway': 2 times
#   'indometacin pharmacokinetics pathway': 2 times
#   'indometacin pharmacodynamics pathway': 2 times
# go.syn: Read 23974 lines with 71934 terms.
#
# No duplicate terms found.
# pw: 2704 unique ids with 3218 unique synonyms
# go.syn: 23974 unique ids with 71934 unique synonyms
# Number of overlapping ids: 0
# Number of overlapping terms: 53
# Overlapping ids:
# Overlapping terms: toll-like receptor 2 signaling pathway
# follicle-stimulating hormone signaling pathway
# thyrotropin signaling pathway
# gm-csf signaling pathway
# wnt signaling pathway
# peroxisome proliferator-activated receptor signaling pathway
# toll-like receptor 6 signaling pathway
# notch signaling pathway
# chemokine (c-c motif) ligand 2 signaling pathway
# toll-like receptor tlr1:tlr2 signaling pathway
# nerve growth factor signaling pathway
# glutamate signaling pathway
# cytokine and chemokine mediated signaling pathway
# nodal signaling pathway
# extrinsic apoptotic pathway
# type i interferon signaling pathway
# hedgehog signaling pathway
# ppar signaling pathway
# vascular endothelial growth factor signaling pathway
# t cell receptor signaling pathway
# intrinsic apoptotic pathway
# luteinizing hormone signaling pathway
# pentose phosphate pathway
# tsh signaling pathway
# clathrin-dependent synaptic vesicle endocytosis
# endocannabinoid signaling pathway
# toll-like receptor 10 signaling pathway
# chemokine (c-x-c motif) ligand 12 signaling pathway
# prolactin signaling pathway
# b cell receptor signaling pathway
# toll-like receptor 4 signaling pathway
# somatostatin signaling pathway
# thromboxane a2 signaling pathway
# stem cell factor signaling pathway
# chemokine (c-c motif) ligand 5 signaling pathway
# leukotriene signaling pathway
# mitochondrial protein import pathway
# toll-like receptor 1 signaling pathway
# toll-like receptor 8 signaling pathway
# hippo signaling pathway
# leukemia inhibitory factor signaling pathway
# gamma-aminobutyric acid signaling pathway
# toll-like receptor 9 signaling pathway
# toll-like receptor 7 signaling pathway
# scf signaling pathway
# bile acid signaling pathway
# thyroid-stimulating hormone signaling pathway
# granulocyte-macrophage colony-stimulating factor signaling pathway
# toll-like receptor 3 signaling pathway
# toll-like receptor signaling pathway
# cannabinoid signaling pathway
# toll-like receptor tlr6:tlr2 signaling pathway
# toll-like receptor 5 signaling pathway
# None
